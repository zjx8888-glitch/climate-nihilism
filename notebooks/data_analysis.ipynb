# %% [markdown]
# # Data analysis (Madeleine Worrall)
#
# # TODO(Madeleine): improve preprocessing pipeline and add EDA here
#
# Labeled data: `data/labeled/`
# Processed manual file: `data/processed/`
# Weak labels: `data/weak_labels/`

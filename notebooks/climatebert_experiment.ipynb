# %% [markdown]
# # ClimateBERT experiment (Jinxi)
#
# Primary training script: `src/climatebert/train.py`
#
# Run from project root:
#
# ```bash
# python src/climatebert/train.py
# python src/climatebert/train.py --finetune --epochs 3
# ```
#
# Outputs: `outputs/climatebert/` · Report: `docs/climatebert_results.md`

# %%
import json
from pathlib import Path

metrics = json.loads(Path("../outputs/climatebert/climatebert_metrics.json").read_text())
mc = metrics["approaches"]["embedding_lr_multiclass"]
print(f"Model: {metrics['embed_model']}")
print(f"Macro F1: {mc['macro_f1']:.3f} | Nihilism F1: {mc['nihilism_f1']:.3f}")

# %% [markdown]
# # TF-IDF experiment (Liu)
#
# # TODO(Liu): improve TF-IDF baseline and document experiments here
#
# Training script: `src/tfidf/train.py`
# Legacy reference: `src/tfidf/legacy_train_evaluate.py`
# Results doc: `docs/tfidf_results.md`
